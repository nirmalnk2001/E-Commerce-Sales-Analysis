# %% [markdown]
# # WALMART SALES DATA ANLAYSIS

# %%
# !pip install mysqlclient

# %%
# !pip3 install pymysql

# %%
import pyodbc
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel("Superstore_USA.xlsx")

# %%
df.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
#
#   Profit  Quantity ordered new  Sales Order ID
# ...

# %%
df.shape
# Out:
# (9426, 24)

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
#filled mean value in the missing value
df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# ## Order Priority

# %%
df['Order Priority'].value_counts()
# Out:
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: Order Priority, dtype: int64

# %%
#two critical values are there in order priority
df['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
df['Order Priority']=df['Order Priority'].replace("Critical ","Critical")

# %%
df['Order Priority'].value_counts()
# Out:
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: Order Priority, dtype: int64

# %%
plt.figure(figsize=(6,4))
ax=sns.countplot(x="Order Priority",data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Count No: of Order Priority")
plt.savefig("Count Of Order Priority.jpg")
plt.show()

# %% [markdown]
# ## Ship Mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
x=df['Ship Mode'].value_counts().index
y=df['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.show()

# %%
plt.figure(figsize=(5,4))
ax=sns.countplot(x="Ship Mode",data=df,color="Blue")
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Ship Modes")
plt.show()

# %%
plt.figure(figsize=(5,4))
ax=sns.countplot(x="Ship Mode",data=df,hue="Product Category")
for bars in ax.containers:
    ax.bar_label(bars)
plt.savefig("ShipModes_ProdCat.jpg")
plt.show()

# %% [markdown]
# ## Product Category

# %%
plt.figure(figsize=(6,4))
ax=sns.countplot(x="Product Category",data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# ### Sub_Product_Categories

# %%
df['Product Sub-Category'].value_counts()
# Out:
# Paper                             1379
# Binders and Binder Accessories    1028
# Telephones and Communication       992
# Office Furnishings                 883
# Computer Peripherals               846
# Pens & Art Supplies                721
# Storage & Organization             610
# Appliances                         492
# Chairs & Chairmats                 440
# Tables                             404
# Office Machines                    376
# Labels                             329
# Envelopes                          272
# Bookcases                          206
# Rubber Bands                       195
# Scissors, Rulers and Trimmers      155
# Copiers and Fax                     98
# Name: Product Sub-Category, dtype: int64

# %%
#Office Supplies
plt.figure(figsize=(10,6))
ax=sns.countplot(x="Product Category",data=df[df["Product Category"]=="Office Supplies"],hue="Product Sub-Category")
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
#Furniture
plt.figure(figsize=(7,5))
ax=sns.countplot(x="Product Category",data=df[df["Product Category"]=="Furniture"],hue="Product Sub-Category")
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
#Technology
plt.figure(figsize=(10,6))
ax=sns.countplot(x="Product Category",data=df[df["Product Category"]=="Technology"],hue="Product Sub-Category")
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# ## Customer Segment

# %%
plt.figure(figsize=(6,4))
ax=sns.countplot(x="Customer Segment",data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df['Product Category'].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %% [markdown]
# ## Order Date

# %% [markdown]
# ### How many Orders on specific Date

# %%
df["Order year"]=df['Order Date'].dt.year

# %%
#Checing Order Year Column in the datasert
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
#Sales in a year
df['Order year'].value_counts()
# Out:
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: Order year, dtype: int64

# %%
plt.figure(figsize=(6,4))
ax=sns.countplot(x="Order year",data=df,color='Blue')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# ## Profit

# %% [markdown]
# ### Product Category wise Profut

# %%
ax=sns.barplot(x="Product Category",y="Profit",data=df,estimator='sum',color='Blue')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# ## State,Region,,City

# %%
df['State or Province'].value_counts()
# Out:
# California              1021
# Texas                    646
# Illinois                 584
# New York                 574
# Florida                  522
# Ohio                     396
# Washington               327
# Michigan                 327
# Pennsylvania             271
# North Carolina           251
# Indiana                  241
# Minnesota                239
# Massachusetts            222
# Georgia                  214
# Virginia                 198
# Maryland                 178
# Colorado                 177
# New Jersey               177
# Wisconsin                169
# Oregon                   168
# Tennessee                166
# Missouri                 161
# Iowa                     156
# Utah                     146
# Arizona                  134
# Kansas                   133
# Maine                    128
# Alabama                  125
# Arkansas                 123
# Idaho                    114
# South Carolina           105
# Oklahoma                 104
# ...

# %%
df['Region'].value_counts()
# Out:
# Central    2899
# East       2289
# West       2284
# South      1954
# Name: Region, dtype: int64

# %%
df['City'].value_counts()
# Out:
# New York City    202
# Los Angeles      196
# Seattle           93
# Chicago           90
# Boston            80
#                 ...
# Holden             1
# Marshfield         1
# Shrewsbury         1
# Stoughton          1
# Westford           1
# Name: City, Length: 1424, dtype: int64

# %% [markdown]
# ## Profir Base Margin

# %%
ax=sns.barplot(x="Product Category",y="Product Base Margin",data=df,estimator='sum',color='Blue')
plt.show()

# %%
import sqlalchemy as sl
engine = sl.create_engine('mssql://NK-LAPTOP\SQLEXPRESS/Ecommerce?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()

# %%
df.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date Profit  \
# 0          Illinois    Addison       60101  2012-05-28 2012-05-30   1.32
# 1        Washington  Anacortes       98221  2010-07-07 2010-07-08   4.56
# 2        Washington  Anacortes       98221  2011-07-27 2011-07-28 -47.64
#
#   Quantity ordered new  Sales Order ID Order year
# ...

# %%
df.to_sql('Sales',con=conn,index=False,if_exists='replace')
# Out:
# -1
